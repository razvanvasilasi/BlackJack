# %%
import random
from IPython.display import clear_output

suits = ['Hearts', 'Diamonds', 'Spades', 'Clubs']
ranks = ['Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace']
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}

class Card():
    
    def __init__(self, rank, suit):
        self.rank = rank
        self.suit = suit
        self.value = values[rank]
        
    def __str__(self):
        return f'{self.rank} of {self.suit}'
    
class Deck():
    
    def __init__(self):
        all_cards = []
        self.all_cards = all_cards
        for rank in ranks:
            for suit in suits:
                self.all_cards.append(Card(rank, suit))
    
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()
    
    def __len__(self):
        return len(newdeck.all_cards)
    
class Player():
    
    def __init__(self, name):
        
        all_cards = []
        self.name = name
        self.all_cards = all_cards
            
    def hit(self, card):
        self.all_cards.append(card)
    
    def hand_value(self):
        result = 0
        for card in self.all_cards:
            result += card.value
        return result
    
class Account():
    
    def __init__(self):
        
        player_balance = ' '
        while type(player_balance) != int:
            player_balance = int(input('Please enter the amount of chips you want to buy: '))
        self.player_balance = player_balance
        
    def add_chips(self, x):
        
        self.player_balance = self.player_balance + x
        
    def place_bet(self):
        
        bet = ' '
        while type(bet) != int:
            bet = int(input('Please place your bet: '))
        self.player_balance = self.player_balance - bet
        return bet
    
class Dealer():
    
    def __init__(self):
        all_cards = []
        self.all_cards = all_cards
        
    def hit(self, card):
        self.all_cards.append(card)
    
    def hand_value(self):
        result = 0
        for card in self.all_cards:
            result += card.value
        return result
    
def table(playercardlist, dealercardlist, playerpoints, dealerpoints, playerbet, chips_balance):
    print('--------------------------------------------------------------------------------')
    print(f"Dealer Cards:")
    print('')
    print('Dealer 1st Card')
    for i in range(len(dealercardlist[1:])): print(dealercardlist[i])
    print('')
    print(f'Dealer Points: {dealerpoints}')
    print('')
    print('')
    print('')
    print('')
    print(f'Player Bet: {playerbet}')
    print('')
    print(f'Player Cards:')
    print('')
    for i in range(len(playercardlist)): print(playercardlist[i])
    print('')
    print('--------------------------------------------------------------------------------')
    print(f'Player Points: {playerpoints}')
    print(f'Player Chips Balance: {chips_balance}')
    print('--------------------------------------------------------------------------------')
    
print('Welcome to BlackJack Table!')
Player = Player('Player')
Dealer = Dealer()
PlayerAccount = Account()
playerbet= 0
game_on =True

while game_on:
    
    newdeck = Deck()
    newdeck.shuffle()
        
    table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
    playerbet = PlayerAccount.place_bet()
    
    
    
    Player.all_cards.append(newdeck.deal_one())
    Player.all_cards.append(newdeck.deal_one())
    Dealer.all_cards.append(newdeck.deal_one())
    Dealer.all_cards.append(newdeck.deal_one())
    
    clear_output()
    table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
    
    deal_cards = True
    
    while deal_cards:
        
        if Player.hand_value() == 21:
            PlayerAccount.add_chips(playerbet*2)
            clear_output()
            table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
            print('Player has won the hand!')
            deal_cards = False
        
        elif Player.hand_value() < 21:
            while Player.hand_value() < 21:
                player_choise = input('Player, do you want to Hit or Stand? (H/S):').upper()
                if player_choise == 'H':
                    Player.all_cards.append(newdeck.deal_one())
                    clear_output()
                    table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                else:
                    if Player.hand_value() == 21:
                        PlayerAccount.add_chips(playerbet*2)
                        clear_output()
                        table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                        print('Player has won the hand!')
                        deal_cards = False
                    else:
                        if Player.hand_value() < 21:
                            while Dealer.hand_value() < 17:
                                Dealer.all_cards.append(newdeck.deal_one())
                                clear_output()
                                table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
            
                            else:
                                if Dealer.hand_value() > 21:
                                    PlayerAccount.add_chips(playerbet*2)
                                    clear_output()
                                    table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                    print('Dealer has BUSTED!\nPlayer has won the hand!')
                                    deal_cards = False
                                    break
                    
                                else:
                                    if Player.hand_value() > Dealer.hand_value():
                                        PlayerAccount.add_chips(playerbet*2)
                                        clear_output()
                                        table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                        print('Player has won the hand!')
                                        deal_cards = False
                                        break
                    
                                    elif Player.hand_value() == Dealer.hand_value():
                                        PlayerAccount.add_chips(playerbet)
                                        clear_output()
                                        table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                        print("It's a draw!")
                                        deal_cards = False
                                        break
                    
                                    else:
                                        clear_output()
                                        table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                        print('Player has lost the hand!')
                                        deal_cards = False
                                        break
                        
                        else:
                            if Player.hand_value() == 21:
                                PlayerAccount.add_chips(playerbet*2)
                                clear_output()
                                table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                print('Player has won the hand!')
                                deal_cards = False
                            else:
                                if Player.hand_value() < 21:
                                    while Dealer.hand_value() < 17:
                                        Dealer.all_cards.append(newdeck.deal_one())
                                        clear_output()
                                        table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
            
                                    else:
                                        if Dealer.hand_value() > 21:
                                            PlayerAccount.add_chips(playerbet*2)
                                            clear_output()
                                            table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                            print('Dealer has BUSTED!\nPlayer has won the hand!')
                                            deal_cards = False
                                            break
                    
                                        else:
                                            if Player.hand_value() > Dealer.hand_value():
                                                PlayerAccount.add_chips(playerbet*2)
                                                clear_output()
                                                table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                                print('Player has won the hand!')
                                                deal_cards = False
                                                break
                    
                                            elif Player.hand_value() == Dealer.hand_value():
                                                PlayerAccount.add_chips(playerbet)
                                                clear_output()
                                                table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                                print("It's a draw!")
                                                deal_cards = False
                                                break
                    
                                            else:
                                                clear_output()
                                                table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                                print('Player has lost the hand!')
                                                deal_cards = False
                                                break
                                                        
            else:
                if Player.hand_value() == 21:
                    PlayerAccount.add_chips(playerbet+playerbet)
                    clear_output()
                    table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                    print('Player has won the hand!')
                    deal_cards = False
                else:
                    if Player.hand_value() < 21:
                        while Dealer.hand_value() < 17:
                            Dealer.all_cards.append(newdeck.deal_one())
                            clear_output()
                            table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
            
                        else:
                            if Dealer.hand_value() > 21:
                                PlayerAccount.add_chips(playerbet*2)
                                clear_output()
                                table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                print('Dealer has BUSTED!\nPlayer has won the hand!')
                                deal_cards = False
                                break
                    
                            else:
                                if Player.hand_value() > Dealer.hand_value():
                                    PlayerAccount.add_chips(playerbet*2)
                                    clear_output()
                                    table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                    print('Player has won the hand!')
                                    deal_cards = False
                                    break
                    
                                elif Player.hand_value() == Dealer.hand_value():
                                    PlayerAccount.add_chips(playerbet)
                                    clear_output()
                                    table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                    print("It's a draw!")
                                    deal_cards = False
                                    break
                    
                                else:
                                    clear_output()
                                    table(Player.all_cards, Dealer. all_cards, Player.hand_value(), Dealer.hand_value(), playerbet, PlayerAccount.player_balance)
                                    print('Player has lost the hand!')
                                    deal_cards = False
                                    break
            
            
        
        else:
            print('Player has BUSTED!')
            deal_cards = False
    
    play_again = input(f'Player, do you want to play another hand (Y/N): ').upper()
    if play_again == 'Y':
        Player.all_cards = []
        Dealer.all_cards = []
        game_on = True
    else:
        game_on = False

# %%
PlayerAccount.player_balance

# %%
PlayerAccount.add_chips(mybet*2)

# %%
mybet = PlayerAccount.place_bet()

# %%
for card in Player.all_cards:
    print(card)
